# %% [markdown]
# 2021年10月2日
# 基本に立ち返って公式チュートリアル見てみるかぁということで、最初の
# https://matplotlib.org/stable/tutorials/introductory/usage.html
# に従ってやっています。

# %%
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Duplicate key in file PosixPath('/usr/local/lib/python3.8/site-packages/matplotlib/mpl-data/matplotlibrc'), line 258 ('font.family : Hiragino sans')

# %% [markdown]
# > Axes (i.e., an area where points can be specified in terms of x-y coordinates, or theta-r in a polar plot, or x-y-z in a 3D plot, etc.).
#
# へええAxesってこういう説明するんだ。
# 「x, yや θ, rなどの座標系で点を特定できる領域」なんだ……

# %%
fig, ax = plt.subplots()  # Create a figure containing a single axes.
ax.plot([1, 2, 3, 4], [1, 4, 2, 3])  # Plot some data on the axes.

# %%
# 明示的にaxesを作らずに、「いまのaxes」に描画する方法。

plt.plot([1, 2, 3, 4], [1, 4, 2, 3])  # Matplotlib plot.

# %% [markdown]
# ### Parts of a Figure
# 図の構成要素
#
# Axes: This is what you think of as 'a plot', it is the region of the image with the data space.
# Figure 1 に対して Axes 多
#
# Axis: These are the number-line-like objects. つまり数直線っぽいモノ。 tickの間隔を決めるLocator、ticklabelの書式を決めるFormatterがAxisの下にいる。

# %% [markdown]
# ### Types of inputs to plotting functions
#
# All of plotting functions expect numpy.array or numpy.ma.masked_array as input. Classes that are 'array-like' such as pandas data objects and numpy.matrix may or may not work as intended. It is best to convert these to numpy.array objects prior to plotting.
# ……サラッと大事なこと言ってる気がする。
# numpyのarrayを入力するのがベストだって言ってるね。
# numpy.arrayは関数だからデータ型のnumpy.ndarrayって言うのが正確だと思うけど。 まぁ良いや。

# %% [markdown]
# 2021年10月4日
# ### The object-oriented interface and the pyplot interface
# 大事。
# > The object-oriented interface and the pyplot interface.
#
# これが最初のページで説明してあるのは良いね。

# %%
x = np.linspace(0, 2, 100)

# Note that even in the OO-style, we use `.pyplot.figure` to create the figure.
# これが謎。何でなの。何でfigとaxを作るためにpltをインポートしなくちゃいけないの。

fig, ax = plt.subplots()  # Create a figure and an axes.
ax.plot(x, x, label='linear')  # Plot some data on the axes.
ax.plot(x, x**2, label='quadratic')  # Plot more data on the axes...
ax.plot(x, x**3, label='cubic')  # ... and some more.
ax.set_xlabel('x label')  # Add an x-label to the axes.
ax.set_ylabel('y label')  # Add a y-label to the axes.
ax.set_title("Simple Plot")  # Add a title to the axes.
ax.legend()  # Add a legend.

# %%
x = np.linspace(0, 2, 100)

plt.plot(x, x, label='linear')  # Plot some data on the (implicit) axes.
plt.plot(x, x**2, label='quadratic')  # etc.
plt.plot(x, x**3, label='cubic')
plt.xlabel('x label')
plt.ylabel('y label')
plt.title("Simple Plot")
plt.legend()

# %% [markdown]
# ### Backend / What is interactive mode?

# %% [markdown]
# 多分関係なさそうなのでそんなにちゃんと読んでない。
#
# 現在のBackendを取得するにはどうするか。StackOverflowにはこうしろって書いてある。
# https://stackoverflow.com/questions/3580027/how-do-you-determine-which-backend-is-being-used-by-matplotlib
#
# 確かに公式ドキュメントにも書いてある。
# https://matplotlib.org/stable/api/matplotlib_configuration_api.html#matplotlib.get_backend

# %%
import matplotlib
matplotlib.get_backend()
# Out:
# 'module://ipykernel.pylab.backend_inline'

# %% [markdown]
# ……
# https://matplotlib.org/stable/tutorials/introductory/usage.html#the-builtin-backends の表の一覧に無いものが出力されたんだけど
# これをどう解釈すれば良いんだ……???

# %% [markdown]
# ### Performance
